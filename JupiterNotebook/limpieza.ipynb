# %%
"""
Set-ExecutionPolicy -Scope Process -ExecutionPolicy RemoteSigned
Get-ExecutionPolicy
"""
# Out:
# '\nSet-ExecutionPolicy -Scope Process -ExecutionPolicy RemoteSigned\nGet-ExecutionPolicy\n'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
#A classification label, with possible values including sadness (0), joy (1), love (2), anger (3), fear (4).

# %%
#Creación del Dataframe del entrenamiento
data = pd.read_csv("../data/raw/training.csv")
df_training=pd.DataFrame(data)



#Cambiamos el nombre de las columnas text y label por x,y respectivamente
df_training.rename(columns={'label':'y'},inplace=True)
df_training.rename(columns={'text':'x'},inplace=True)
df_training
# Out:
#                                                        x  y
# 0                                i didnt feel humiliated  0
# 1      i can go from feeling so hopeless to so damned...  0
# 2       im grabbing a minute to post i feel greedy wrong  3
# 3      i am ever feeling nostalgic about the fireplac...  2
# 4                                   i am feeling grouchy  3
# ...                                                  ... ..
# 15995  i just had a very brief time in the beanbag an...  0
# 15996  i am now turning and i feel pathetic that i am...  0
# 15997                     i feel strong and good overall  1
# 15998  i feel like this was such a rude comment and i...  3
# 15999  i know a lot but i feel so stupid because i ca...  0
#
# [16000 rows x 2 columns]

# %%
#Creación del Dataframe de las pruebas
data_test = pd.read_csv('../data/raw/test.csv')
df_test= pd.DataFrame(data= data_test)



#Cambiamos el nombre de las columnas text y label por x,y respectivamente
df_test.rename(columns={'text':'x'}, inplace=True)
df_test.rename(columns={'label':'y'}, inplace=True)

df_test
# Out:
#                                                       x  y
# 0     im feeling rather rotten so im not very ambiti...  0
# 1             im updating my blog because i feel shitty  0
# 2     i never make her separate from me because i do...  0
# 3     i left with my bouquet of red and yellow tulip...  1
# 4       i was feeling a little vain when i did this one  0
# ...                                                 ... ..
# 1995  i just keep feeling like someone is being unki...  3
# 1996  im feeling a little cranky negative after this...  3
# 1997  i feel that i am useful to my people and that ...  1
# 1998  im feeling more comfortable with derby i feel ...  1
# 1999  i feel all weird when i have to meet w people ...  4
#
# [2000 rows x 2 columns]

# %%
#df_test.to_csv('df_test.csv',index=False)
#df_training.to_csv('df_training.csv',index=False)

# %%
# Diccionario para mapear número a emoción
emotion_labels = {0: 'Sadness', 1: 'Joy', 2: 'Love', 3: 'Anger', 4: 'Fear'}
df_training['emotion'] = df_training['y'].map(emotion_labels)

# Gráfico 1: Conteo por emoción
plt.figure(figsize=(8,5))
sns.countplot(data=df_training, x='emotion', palette='Set2')
plt.title('Distribución de emociones en el dataset')
plt.xlabel('Emoción')
plt.ylabel('Cantidad de ejemplos')
plt.grid(axis='y')
plt.show()
# Out:
# C:\Users\angul\AppData\Local\Temp\ipykernel_15172\3084318906.py:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_training, x='emotion', palette='Set2')

# %%
# Calculamos la cantidad de palabras por texto
df_training['text_length'] = df_training['x'].apply(lambda x: len(x.split()))

# Gráfico 2: Histograma de longitudes
plt.figure(figsize=(8,5))
sns.histplot(df_training['text_length'], bins=40, kde=True, color='skyblue')
plt.title('Distribución de la longitud de los textos')
plt.xlabel('Cantidad de palabras')
plt.ylabel('Frecuencia')
plt.grid(True)
plt.show()

# %%
# Gráfico 3: Boxplot de longitud por emoción
plt.figure(figsize=(8,5))
sns.boxplot(data=df_training, x='emotion', y='text_length', palette='Pastel2')
plt.title('Longitud de textos según la emoción')
plt.xlabel('Emoción')
plt.ylabel('Cantidad de palabras')
plt.grid(True)
plt.show()
# Out:
# C:\Users\angul\AppData\Local\Temp\ipykernel_15172\3672450781.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df_training, x='emotion', y='text_length', palette='Pastel2')
